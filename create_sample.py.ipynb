# %%
#테스트용 샘플 데이터 셋 만들기 이름 / 나이 / 전화번호
import random
import pandas as pd
from pandas import DataFrame

#샘플 레코드 갯수
record_num = 2000

#성씨 - 82개
last_name = ["김", "이", "박", "최", "정", "강", "조", "윤", "장", "임", "한", "오", "서", "신", "권", "황", "안",
"송", "류", "전", "홍", "고", "문", "양", "손", "배", "조", "백", "허", "유", "남", "심", "노", "정", "하", "곽", "성", "차", "주",
"우", "구", "신", "임", "나", "전", "민", "유", "진", "지", "엄", "채", "원", "천", "방", "공", "강", "현", "함", "변", "염", "양",
"변", "여", "추", "노", "도", "소", "신", "석", "선", "설", "마", "길", "주", "연", "방", "위", "표", "명", "기", "반", "왕", "금",
"옥", "육", "인", "맹", "제", "모", "장", "남", "탁", "국", "여", "진", "어", "은", "편", "구", "용"]

#이름 - 20개 (추가예정)
name = ["민준","서준","예준","도윤","시우","주원","하준","지호","지후","준서","서연","서윤","지우","서현","민서","하은","하윤","윤서","지유","지민"]

#지역
location = ["서울","부산", "대구", "인천", "광주", "대전", "울산","경기","세종", "강원", "충북", "충남","전북","전남","경북","경남","제주"]

#병명
disease = ['감기','몸살','위염','두통','타박상']

#혈액형
blood_type = ['A','B','O','AB']
blood_type_portion = [34,27,28,11]

name_list = []
age_list = []
phone_list = []
location_list = []
disease_list = []
blood_list = []
smoke_list = []

result = {"이름":name_list,"나이":age_list,"전화번호":phone_list,"거주지역":location_list,"병명":disease_list,"혈액형":blood_list,"흡연여부":smoke_list}

for i in range(0, record_num, 1):
    #랜덤 이름 하나 생성 - 성씨
    last_portion = random.randrange(0,100)
    if (last_portion < 22):
        #김씨 21퍼
        last_rand = 0
    elif (22 <= last_portion <= 37):
        #이씨 15퍼
        last_rand = 1
    elif (37 < last_portion <= 46):
        #박씨 9퍼
        last_rand = 2
    elif (47 <= last_portion <= 52):
        #정씨 5퍼
        last_rand = 3
    elif (53 <= last_portion <= 58):
        #최씨 5퍼 
        last_rand = 4
    elif (59 <= last_portion <= 62):
        #조씨 3퍼
        last_rand = 5
    elif (63 <= last_portion <= 65):
        #강씨 2퍼
        last_rand = 6
    elif (66 <= last_portion <= 68):
        #장씨 2퍼
        last_rand = 7
    elif (69 <= last_portion <= 71):
        #윤씨 2퍼
        last_rand = 8
    elif (72 <= last_portion <= 74):
        #유씨 2퍼
        last_rand = 9
    elif (75 <= last_portion <= 77):
        #임씨 2퍼
        last_rand = 10
    else:
        #나머지 성씨
        last_rand = random.randrange(11,81)
    
    #랜덤 이름 하나 생성 - 이름
    name_portion = random.randrange(0,100)
    if (name_portion < 7):
        #1위 7퍼
        name_type = 0
    elif (7 <= name_portion <= 12):
        #2위 6퍼
        name_type = 1
    elif (13 <= name_portion <= 17):
        #3위 5퍼
        name_type = 2
    elif (18 <= name_portion <= 22):
        #4위 5퍼
        name_type = 3
    elif (23 <= name_portion <= 27):
        #5위 5퍼
        name_type = 4
    elif (28 <= name_portion <= 32):
        #6위 5퍼
        name_type = 5
    elif (33 <= name_portion <= 37):
        #7위 5퍼
        name_type = 6
    elif (38 <= name_portion <= 42):
        #8위 5퍼
        name_type = 7
    elif (43 <= name_portion <= 47):
        #9위 5퍼
        name_type = 8
    elif (48 <= name_portion <= 52):
        #10위 5퍼
        name_type = 9
    elif (53 <= name_portion <= 57):
        #11위 5퍼
        name_type = 10
    elif (58 <= name_portion <= 61):
        #12위 4퍼
        name_type = 11
    else:
        #나머지 이름
        name_type = random.randrange(13,20)

    #랜덤 나이 생성
    age_portion = random.randrange(0,100)
    if (age_portion < 4):
        #0-4세 3.6% 약 4%
        age = random.randrange(0,5)
    elif (5 <= name_portion <= 9):
        #5-9세 약 4%
        age = random.randrange(5,10)
    elif (10 <= name_portion <= 13):
        #5-9세 약 7%
        age = random.randrange(10,15)
    elif (14 <= name_portion <= 17):
        #5-9세 약 7%
        age = random.randrange(15,20)
    elif (18 <= name_portion <= 22):
        #5-9세 약 7%
        age = random.randrange(20,25)
    elif (23 <= name_portion <= 29):
        #25-29세 약 7%
        age = random.randrange(25,30)
    elif (30 <= name_portion <= 36):
        #5-9세 약 7%
        age = random.randrange(30,35)
    elif (37 <= name_portion <= 43):
        #5-9세 약 7%
        age = random.randrange(35,40)
    elif (44 <= name_portion <= 51):
        #5-9세 약 7%
        age = random.randrange(40,45)
    elif (52 <= name_portion <= 58):
        #5-9세 약 7%
        age = random.randrange(45,50)
    elif (59 <= name_portion <= 66):
        #50-54세 약 7%
        age = random.randrange(50,55)   
    elif (67 <= name_portion <= 74):
        #5-9세 약 7%
        age = random.randrange(55,60)
    elif (75 <= name_portion <= 81):
        #5-9세 약 7%
        age = random.randrange(60,65)
    elif (82 <= name_portion <= 86):
        #50-54세 약 7%
        age = random.randrange(65,70)   
    elif (87 <= name_portion <= 90):
        #5-9세 약 7%
        age = random.randrange(70,75)
    elif (91 <= name_portion <= 93):
        #50-54세 약 7%
        age = random.randrange(75,80)   
    elif (94 <= name_portion <= 95):
        #5-9세 약 7%
        age = random.randrange(80,85)
    elif (96 <= name_portion <= 97):
        #5-9세 약 7%
        age = random.randrange(85,90)
    elif (98 <= name_portion <=99):
        age = random.randrange(90,100)
    else:
        age = random.randrange(100,120)
    if (age < 10):
        age_str = '0'+str(age)
    else:
        age_str = str(age)
    
    #거주지역 45 12 8
    location_portion = random.randrange(0,100)
    if (location_portion < 45):
        #1위 45퍼 서울
        location_type = 0
    elif (46 <= location_portion <= 57):
        #2위 12퍼 부산
        location_type = 1
    elif (58 <= location_portion <= 65):
        #3위 8퍼 대구
        location_type = 2
    elif (66 <= location_portion <= 73):
        #4위 8퍼 인천
        location_type = 3
    elif (74 <= location_portion <= 81):
        #5위 8퍼 광주
        location_type = 4
    elif (82 <= location_portion <= 89):
        #6위 8퍼 대전
        location_type = 5
    elif (90 <= location_portion <= 93):
        #7위 3퍼 울산
        location_type = 6
    elif (94 <= location_portion <= 97):
        #8위 3퍼 경기
        location_type = 7
    else:
        location_type = random.randrange(8,16)


    #랜덤 전화번호 하나 생성
    phone_num = "010-"
    for j in range(0,4,1):
        phone_num_rand = random.randrange(1,10)
        phone_num += str(phone_num_rand)
    phone_num += "-"
    for k in range(0,4,1):
        phone_num_rand = random.randrange(1,10)
        phone_num += str(phone_num_rand)
        
    #병명 생성 (가중치 고려X)
    disease_now = disease[random.randrange(0,5)]
    
    #혈액형 생성 (가중치 고려O)
    blood_type_portrand = random.randrange(0,100)
    if (blood_type_portrand < 34):
        blood_type_now = blood_type[0]
    elif (34<= blood_type_portrand <= 60):
        blood_type_now = blood_type[1]
    elif (61 <= blood_type_portrand < 88):
        blood_type_now = blood_type[2]
    else:
        blood_type_now = blood_type[3]
        
    #흡연여부
    smoking_portion = random.randrange(0,4)
    if (smoking_portion == 0):
        smoking = 'O'
    else:
        smoking = 'X'
        
    name_list.append(last_name[last_rand] + name[name_type])
    age_list.append(age_str)
    phone_list.append(str(phone_num))
    location_list.append(location[location_type])
    disease_list.append(disease_now)
    blood_list.append(blood_type_now)
    smoke_list.append(smoking)
    
    
result_df = DataFrame(result)
print(result_df)
result_df.to_csv('sample.csv', sep=',', na_rep='NaN', encoding = 'utf-8',index = False)
# Out:
#        이름  나이           전화번호 거주지역   병명 혈액형 흡연여부
# 0     홍하은  59  010-6161-5144   대전   몸살   B    O
# 1     김민준  09  010-5979-2124   광주  타박상   B    X
# 2     조시우  28  010-3254-7772   경기   감기   O    X
# 3     윤준서  00  010-8236-1811   광주  타박상   A    X
# 4     도민서  77  010-8566-3245   부산   감기   B    O
# ...   ...  ..            ...  ...  ...  ..  ...
# 1995  손하윤  67  010-5749-8435   서울  타박상   B    O
# 1996  박지민  83  010-6575-5418   부산   두통   O    O
# 1997  이하준  31  010-3526-7345   서울   감기  AB    O
# 1998  이윤서  57  010-6636-7934   서울   두통   B    X
# 1999  김민서  52  010-3488-9853   서울   감기   O    X
#
# [2000 rows x 7 columns]
